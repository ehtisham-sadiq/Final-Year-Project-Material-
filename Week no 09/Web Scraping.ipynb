# %%
# import sys
# !{sys.executable} -m pip install --upgrade pip -q
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install beautifulsoup4 -q
# !{sys.executable} -m pip install --upgrade lxml -q
# !{sys.executable} -m pip install html5lib -q

# %%
import requests
import bs4 # bs4 is a dummy package managed by the developer of Beautiful Soup to prevent name squatting
from bs4 import BeautifulSoup
import lxml
import html5lib

# %%
import requests
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'JSONDecodeError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet_version', 'charset_normalizer_version', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %%
source = requests.get("https://www.imdb.com/chart/top/")
source.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(source.text, 'lxml')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
movies = soup.find('tbody',class_="lister-list").find_all('tr')
print(movies)
# Out:
# [<tr>
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="9.235498623459206" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="2698282" name="nv"></span>
# <span data-value="-1.7645013765407942" name="ur"></span>
# <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.2 based on 2,698,282 user ratings">9.2</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# ...

# %%
print(len(movies))
# Out:
# 250

# %%
import openpyxl

# %%
excel = openpyxl.Workbook()
print(excel.sheetnames)
# Out:
# ['Sheet']

# %%
sheet = excel.active
sheet.title = 'Top Rated Movies'
print(excel.sheetnames)
# Out:
# ['Top Rated Movies']

# %%
sheet.append(["Rank","Movie Name","Year","IMDB Rating"])

# %%
for movie in movies:
    #name = movie.find('td',claas_="titleColumn")
    #movie.find('td', class_ = "titleColumn")
    name = movie.find('td', class_ = "titleColumn").a.text
    rank = movie.find('td', class_ = "titleColumn").get_text(strip=True).split(".")[0]
    year = movie.find('td', class_ = "titleColumn").span.text.strip('()')
    rating = movie.find('td', class_ = "ratingColumn").strong.text
    sheet.append([rank,name,year,rating])
    #print(name)
    #print(rank)
    #print(year)
    #print(rating)

# %%
excel.save("IMDB Movie Ratings.xls")

# %%
import pandas as pd
pd.read_excel('IMDB Movie Ratings.xls').head()
# Out:
#    Rank                Movie Name  Year  IMDB Rating
# 0     1  The Shawshank Redemption  1994          9.2
# 1     2             The Godfather  1972          9.2
# 2     3           The Dark Knight  2008          9.0
# 3     4     The Godfather Part II  1974          9.0
# 4     5              12 Angry Men  1957          9.0

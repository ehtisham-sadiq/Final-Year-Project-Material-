# %% [markdown]
# #### importing dataset

# %%
import pandas as pd
df = pd.read_csv("dataset/weatherAUS.csv")
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# ...

# %% [markdown]
# #### EDA

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# #### Finding correlation

# %%
df.corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3628\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# ...

# %% [markdown]
# ## Bivariant Analysis

# %% [markdown]
# ### Numerical to Numerical Analysis

# %% [markdown]
# #### Column : Humidity9am

# %%
# print number of labels in Humidity9am variable
print('Humidity9am conatins', df.Humidity9am.nunique(), 'labels')
# Out:
# Humidity9am conatins 101 labels

# %%
df.Humidity9am.value_counts()
# Out:
# 99.0    3391
# 70.0    3026
# 69.0    3023
# 65.0    3014
# 68.0    3011
#         ...
# 4.0       20
# 3.0       10
# 2.0        8
# 1.0        5
# 0.0        1
# Name: Humidity9am, Length: 101, dtype: int64

# %%
df.Humidity9am.isna().sum()
# Out:
# 2654

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=12
matplotlib.rcParams['figure.figsize']=(10,10)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
sns.histplot(df.Humidity9am)
# Out:
# <AxesSubplot: xlabel='Humidity9am', ylabel='Count'>

# %%
sns.scatterplot( data=df.sample(1000), x='Humidity3pm', y='Humidity9am')
# Out:
# <AxesSubplot: xlabel='Humidity3pm', ylabel='Humidity9am'>

# %%
sns.scatterplot( data=df.sample(2000), x='Pressure9am', y='Humidity9am')
# Out:
# <AxesSubplot: xlabel='Pressure9am', ylabel='Humidity9am'>

# %%
sns.scatterplot( data=df.sample(2000), x='Pressure3pm', y='Humidity9am')
# Out:
# <AxesSubplot: xlabel='Pressure3pm', ylabel='Humidity9am'>

# %% [markdown]
# #### Humidity3pm

# %%
# print number of labels in Humidity3pm variable
print('Humidity3pm conatins', df.Humidity3pm.nunique(), 'labels')
# Out:
# Humidity3pm conatins 101 labels

# %%
df.Humidity3pm.value_counts()
# Out:
# 52.0    2751
# 55.0    2738
# 57.0    2728
# 53.0    2697
# 59.0    2690
#         ...
# 4.0      113
# 3.0       63
# 2.0       35
# 1.0       26
# 0.0        4
# Name: Humidity3pm, Length: 101, dtype: int64

# %%
df.Humidity3pm.isna().sum()
# Out:
# 4507

# %%
sns.scatterplot( data=df.sample(2000), x='Sunshine', y='Humidity3pm')
# Out:
# <AxesSubplot: xlabel='Sunshine', ylabel='Humidity3pm'>

# %%
sns.scatterplot( data=df.sample(2000), x='Temp3pm', y='Humidity3pm')
# Out:
# <AxesSubplot: xlabel='Temp3pm', ylabel='Humidity3pm'>

# %% [markdown]
# ## Analysis of categorical to categorical columns

# %%
cat_columns = df.select_dtypes('object').columns.to_list()
cat_columns
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %% [markdown]
# ## WindDir9am and RainTomorrow

# %%
ct_counts = df.groupby(['WindDir9am', 'RainTomorrow']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'RainTomorrow', columns = 'WindDir9am', values = 'count')

# %%
sns.heatmap(ct_counts)
# Out:
# <AxesSubplot: xlabel='WindDir9am', ylabel='RainTomorrow'>

# %%
pd.to_datetime(df.Date).dt.year
# Out:
# 0         2008
# 1         2008
# 2         2008
# 3         2008
# 4         2008
#           ...
# 145455    2017
# 145456    2017
# 145457    2017
# 145458    2017
# 145459    2017
# Name: Date, Length: 145460, dtype: int64

# %%
plt.title("Number of rows per Year")
sns.countplot(y=pd.to_datetime(df.Date).dt.year)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['Year'] = df['Date'].dt.year

# %% [markdown]
# #### Date in Year and RainTomorrow

# %%
ct_counts1 = df.groupby(['Year', 'RainTomorrow']).size()
ct_counts1 = ct_counts1.reset_index(name = 'count')
ct_counts1 = ct_counts1.pivot(index = 'RainTomorrow', columns = 'Year', values = 'count')

# %%
sns.heatmap(ct_counts1)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='RainTomorrow'>

# %% [markdown]
# ## Analysis of Numerical to Categorical Columns

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=12
matplotlib.rcParams['figure.figsize']=(8,8)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
sns.barplot(data=df, x="RainTomorrow", y="Humidity3pm")
# Out:
# <AxesSubplot: xlabel='RainTomorrow', ylabel='Humidity3pm'>

# %%
sns.barplot(data=df, x="RainToday", y="Humidity3pm")
# Out:
# <AxesSubplot: xlabel='RainToday', ylabel='Humidity3pm'>

# %%
matplotlib.rcParams['figure.figsize']=(8,8)
sns.barplot(data=df, x="RainToday", y="Pressure3pm")
# Out:
# <AxesSubplot: xlabel='RainToday', ylabel='Pressure3pm'>

# %%
matplotlib.rcParams['figure.figsize']=(10,10)
sns.barplot(data=df, x="WindGustDir", y="Pressure9am")
# Out:
# <AxesSubplot: xlabel='WindGustDir', ylabel='Pressure9am'>
